# %%
import pandas as pd

# %%
import numpy as np

# %%
anime = pd.read_csv('anime.csv')

# %%
anime
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 2      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 3                                       Sci-Fi, Thriller     TV       24
# 4      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# ...                                                  ...    ...      ...
# 12289                                             Hentai    OVA        1
# 12290                                             Hentai    OVA        1
# 12291                                             Hentai    OVA        4
# 12292                                             Hentai    OVA        1
# 12293                                             Hentai  Movie        1
#
#        rating  members
# 0        9.37   200630
# 1        9.26   793665
# 2        9.25   114262
# 3        9.17   673572
# 4        9.16   151266
# ...       ...      ...
# 12289    4.15      211
# 12290    4.28      183
# 12291    4.88      219
# 12292    4.98      175
# 12293    5.46      142
#
# [12294 rows x 7 columns]

# %%
df = pd.DataFrame([[1,'Bob', 'Builder'],
                  [2,'Sally', 'Baker']], columns = [1, 2, 3])

# %%
df
# Out:
#    1      2        3
# 0  1    Bob  Builder
# 1  2  Sally    Baker

# %%
anime_copy = anime.copy()

# %%
anime_copy
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 2      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 3                                       Sci-Fi, Thriller     TV       24
# 4      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# ...                                                  ...    ...      ...
# 12289                                             Hentai    OVA        1
# 12290                                             Hentai    OVA        1
# 12291                                             Hentai    OVA        4
# 12292                                             Hentai    OVA        1
# 12293                                             Hentai  Movie        1
#
#        rating  members
# 0        9.37   200630
# 1        9.26   793665
# 2        9.25   114262
# 3        9.17   673572
# 4        9.16   151266
# ...       ...      ...
# 12289    4.15      211
# 12290    4.28      183
# 12291    4.88      219
# 12292    4.98      175
# 12293    5.46      142
#
# [12294 rows x 7 columns]

# %%
anime.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
anime.tail()
# Out:
#        anime_id                                               name   genre  \
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami  Hentai
# 12290      5543                                        Under World  Hentai
# 12291      5621                     Violence Gekiga David no Hoshi  Hentai
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...  Hentai
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!  Hentai
#
#         type episodes  rating  members
# 12289    OVA        1    4.15      211
# 12290    OVA        1    4.28      183
# 12291    OVA        4    4.88      219
# 12292    OVA        1    4.98      175
# 12293  Movie        1    5.46      142

# %%
len(anime)
# Out:
# 12294

# %%
len(anime['genre'].unique())
# Out:
# 3265

# %%
anime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12294 entries, 0 to 12293
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  12294 non-null  int64
#  1   name      12294 non-null  object
#  2   genre     12232 non-null  object
#  3   type      12269 non-null  object
#  4   episodes  12294 non-null  object
#  5   rating    12064 non-null  float64
#  6   members   12294 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 480.3+ KB

# %%
anime.dtypes
# Out:
# anime_id      int64
# name         object
# genre        object
# type         object
# episodes     object
# rating      float64
# members       int64
# dtype: object

# %%
anime.describe()
# Out:
#            anime_id        rating       members
# count  12294.000000  12064.000000  1.229400e+04
# mean   14058.221653      6.473902  1.807134e+04
# std    11455.294701      1.026746  5.482068e+04
# min        1.000000      1.670000  5.000000e+00
# 25%     3484.250000      5.880000  2.250000e+02
# 50%    10260.500000      6.570000  1.550000e+03
# 75%    24794.500000      7.180000  9.437000e+03
# max    34527.000000     10.000000  1.013917e+06

# %%
anime['type'].value_counts()
# Out:
# type
# TV         3787
# OVA        3311
# Movie      2348
# Special    1676
# ONA         659
# Music       488
# Name: count, dtype: int64

# %%
anime['name']
# Out:
# 0                                           Kimi no Na wa.
# 1                         Fullmetal Alchemist: Brotherhood
# 2                                                 Gintama°
# 3                                              Steins;Gate
# 4                                            Gintama&#039;
#                                ...
# 12289         Toushindai My Lover: Minami tai Mecha-Minami
# 12290                                          Under World
# 12291                       Violence Gekiga David no Hoshi
# 12292    Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293                     Yasuji no Pornorama: Yacchimae!!
# Name: name, Length: 12294, dtype: object

# %%
anime[['name', 'genre', 'rating']]
# Out:
#                                                     name  \
# 0                                         Kimi no Na wa.
# 1                       Fullmetal Alchemist: Brotherhood
# 2                                               Gintama°
# 3                                            Steins;Gate
# 4                                          Gintama&#039;
# ...                                                  ...
# 12289       Toushindai My Lover: Minami tai Mecha-Minami
# 12290                                        Under World
# 12291                     Violence Gekiga David no Hoshi
# 12292  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre  rating
# 0                   Drama, Romance, School, Supernatural    9.37
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...    9.26
# 2      Action, Comedy, Historical, Parody, Samurai, S...    9.25
# 3                                       Sci-Fi, Thriller    9.17
# 4      Action, Comedy, Historical, Parody, Samurai, S...    9.16
# ...                                                  ...     ...
# 12289                                             Hentai    4.15
# 12290                                             Hentai    4.28
# 12291                                             Hentai    4.88
# 12292                                             Hentai    4.98
# 12293                                             Hentai    5.46
#
# [12294 rows x 3 columns]

# %%
anime_copy.drop(['episodes', 'rating', 'members'], axis = 1)
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type
# 0                   Drama, Romance, School, Supernatural  Movie
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV
# 2      Action, Comedy, Historical, Parody, Samurai, S...     TV
# 3                                       Sci-Fi, Thriller     TV
# 4      Action, Comedy, Historical, Parody, Samurai, S...     TV
# ...                                                  ...    ...
# 12289                                             Hentai    OVA
# 12290                                             Hentai    OVA
# 12291                                             Hentai    OVA
# 12292                                             Hentai    OVA
# 12293                                             Hentai  Movie
#
# [12294 rows x 4 columns]

# %%
df1 = anime_copy[0:2]
df2 = anime_copy[3:5]
pd.concat([df1, df2])
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 3   673572
# 4   151266

# %%
df1 = pd.DataFrame({'lkey': ['foo', 'bar', 'baz', 'foo'],
                    'value': [1, 2, 3, 5]})
df2 = pd.DataFrame({'rkey': ['foo', 'bar', 'baz', 'foo'],
                    'value': [5, 6, 7, 8]})

# %%
df1.merge(df2, left_on='lkey', right_on='rkey')
# Out:
#   lkey  value_x rkey  value_y
# 0  foo        1  foo        5
# 1  foo        1  foo        8
# 2  bar        2  bar        6
# 3  baz        3  baz        7
# 4  foo        5  foo        5
# 5  foo        5  foo        8

# %%
anime.loc[0:3]
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572

# %%
anime.iloc[0:3]
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
#
#    members
# 0   200630
# 1   793665
# 2   114262

# %%
anime[anime['type'].isin(['Movie', 'TV'])]
# Out:
#        anime_id                              name  \
# 0         32281                    Kimi no Na wa.
# 1          5114  Fullmetal Alchemist: Brotherhood
# 2         28977                          Gintama°
# 3          9253                       Steins;Gate
# 4          9969                     Gintama&#039;
# ...         ...                               ...
# 11738      3038           Senya Ichiya Monogatari
# 11805      2755                         Cleopatra
# 12244     11141                      Blue Seagull
# 12258     20007     Hi Gekiga Ukiyoe Senya Ichiya
# 12293     26081  Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 2      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 3                                       Sci-Fi, Thriller     TV       24
# 4      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# ...                                                  ...    ...      ...
# 11738                                    Fantasy, Hentai  Movie        1
# 11805                                 Hentai, Historical  Movie        1
# 12244                                     Action, Hentai  Movie        1
# 12258                                     Action, Hentai  Movie        1
# 12293                                             Hentai  Movie        1
#
#        rating  members
# 0        9.37   200630
# 1        9.26   793665
# 2        9.25   114262
# 3        9.17   673572
# 4        9.16   151266
# ...       ...      ...
# 11738    6.18     1394
# 11805    6.06     1709
# 12244    4.60      337
# 12258    1.92      129
# 12293    5.46      142
#
# [6135 rows x 7 columns]

# %%
anime[anime['type'] == 'TV']
# Out:
#        anime_id                                               name  \
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# 5         32935  Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...
# ...         ...                                                ...
# 11104     34522                          Wake Up, Girls! Shin Shou
# 11106     34467                             Yami Shibai 4th Season
# 11107     32615                                        Youjo Senki
# 11110     34284  Yuuki Yuuna wa Yuusha de Aru: Washio Sumi no Shou
# 11111     34445       Yuuki Yuuna wa Yuusha de Aru: Yuusha no Shou
#
#                                                    genre type episodes  \
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...   TV       64
# 2      Action, Comedy, Historical, Parody, Samurai, S...   TV       51
# 3                                       Sci-Fi, Thriller   TV       24
# 4      Action, Comedy, Historical, Parody, Samurai, S...   TV       51
# 5                 Comedy, Drama, School, Shounen, Sports   TV       10
# ...                                                  ...  ...      ...
# 11104                                       Drama, Music   TV  Unknown
# 11106                     Dementia, Horror, Supernatural   TV  Unknown
# 11107                                    Magic, Military   TV  Unknown
# 11110               Drama, Fantasy, Magic, Slice of Life   TV        6
# 11111               Drama, Fantasy, Magic, Slice of Life   TV        6
#
#        rating  members
# 1        9.26   793665
# 2        9.25   114262
# 3        9.17   673572
# 4        9.16   151266
# 5        9.15    93351
# ...       ...      ...
# 11104     NaN      381
# 11106     NaN     1838
# 11107     NaN     6652
# 11110     NaN     2593
# 11111     NaN     4439
#
# [3787 rows x 7 columns]

# %%
anime[anime['episodes'] > '100']
# Out:
#        anime_id                              name  \
# 1          5114  Fullmetal Alchemist: Brotherhood
# 2         28977                          Gintama°
# 3          9253                       Steins;Gate
# 4          9969                     Gintama&#039;
# 6         11061            Hunter x Hunter (2011)
# ...         ...                               ...
# 12282     34388   Shikkoku no Shaga The Animation
# 12284     26031                Super Erotic Anime
# 12285     34399                  Taimanin Asagi 3
# 12286     10368               Teleclub no Himitsu
# 12291      5621    Violence Gekiga David no Hoshi
#
#                                                    genre type episodes  \
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...   TV       64
# 2      Action, Comedy, Historical, Parody, Samurai, S...   TV       51
# 3                                       Sci-Fi, Thriller   TV       24
# 4      Action, Comedy, Historical, Parody, Samurai, S...   TV       51
# 6                Action, Adventure, Shounen, Super Power   TV      148
# ...                                                  ...  ...      ...
# 12282                                             Hentai  OVA  Unknown
# 12284                                             Hentai  OVA        2
# 12285                       Demons, Hentai, Supernatural  OVA  Unknown
# 12286                                             Hentai  OVA        2
# 12291                                             Hentai  OVA        4
#
#        rating  members
# 1        9.26   793665
# 2        9.25   114262
# 3        9.17   673572
# 4        9.16   151266
# 6        9.13   425855
# ...       ...      ...
# 12282     NaN      195
# 12284    4.45      118
# 12285     NaN      485
# 12286    4.67      148
# 12291    4.88      219
#
# [6493 rows x 7 columns]

# %%
anime.sort_values('episodes', ascending = 1)
# Out:
#        anime_id                                            name  \
# 0         32281                                  Kimi no Na wa.
# 7252      22205                            Be Blues! Ao ni Nare
# 7250      29141          Atama wa Tsukaiyou. Card mo Tsukaiyou.
# 7249       2249                                       Amon Saga
# 7246      22467                           Minihams no Ai no Uta
# ...         ...                                             ...
# 10474     32663  Tama &amp; Friends: Uchi no Tama Shirimasenka?
# 3055      13163        Furusato Saisei: Nihon no Mukashibanashi
# 3051       7643                                        Domo-kun
# 10731     33776                  Watashitachi, Luck Logic-bu! 2
# 11342     33768             Oide yo! Shiritsu Yarimakuri Gakuen
#
#                                       genre     type episodes  rating  members
# 0      Drama, Romance, School, Supernatural    Movie        1    9.37   200630
# 7252                        Shounen, Sports      ONA        1    5.60      154
# 7250                                 Comedy  Special        1    5.60      177
# 7249             Action, Adventure, Fantasy      OVA        1    5.60     2781
# 7246                            Kids, Music    Music        1    5.61      161
# ...                                     ...      ...      ...     ...      ...
# 10474                       Adventure, Kids       TV  Unknown    6.67       73
# 3055         Historical, Kids, Supernatural       TV  Unknown    7.09     6820
# 3051            Comedy, Kids, Slice of Life       TV  Unknown    7.09     1167
# 10731                        Comedy, School      ONA  Unknown    5.85      323
# 11342                                Hentai      OVA  Unknown    6.79     1059
#
# [12294 rows x 7 columns]

# %%
anime.groupby('type').count()
# Out:
#          anime_id  name  genre  episodes  rating  members
# type
# Movie        2348  2348   2306      2348    2297     2348
# Music         488   488    488       488     488      488
# ONA           659   659    655       659     652      659
# OVA          3311  3311   3310      3311    3285     3311
# Special      1676  1676   1674      1676    1671     1676
# TV           3787  3787   3777      3787    3671     3787

# %%
anime.groupby(["type"]).agg({
  "rating": "sum",
  "episodes": "count",
  "name": "last"
}).reset_index()
# Out:
#       type    rating  episodes  \
# 0    Movie  14512.58      2348
# 1    Music   2727.43       488
# 2      ONA   3679.43       659
# 3      OVA  20942.60      3311
# 4  Special  10900.77      1676
# 5       TV  25338.34      3787
#
#                                                 name
# 0                   Yasuji no Pornorama: Yacchimae!!
# 1                                       Yuu no Mahou
# 2                                     Docchi mo Maid
# 3  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 4                   Junjou Shoujo Et Cetera Specials
# 5       Yuuki Yuuna wa Yuusha de Aru: Yuusha no Shou
